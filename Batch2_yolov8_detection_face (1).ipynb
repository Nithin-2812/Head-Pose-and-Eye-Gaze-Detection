# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Pip install method (recommended)

#!pip install ultralytics==8.0.28
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %%
ROOT_PATH = "/content/drive/MyDrive/codedisha/Face_yolov8_detect"

# %%
# !pwd
# Out:
# /content

# %%
# %cd "/content/drive/MyDrive/codedisha/Face_yolov8_detect"
# Out:
# /content/drive/MyDrive/codedisha/Face_yolov8_detect

# %%
# !pwd
# Out:
# /content/drive/MyDrive/codedisha/Face_yolov8_detect

# %%
# !ls
# Out:
# Batch1_1280-1280  Batch1_dataset.yaml  Batch1_yolov8_detection_teeth.ipynb  runs  yolov8n.pt

# %% [markdown]
# ## Custom Training

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/codedisha/Face_yolov8_detect/Batch2_dataset.yaml epochs=150 imgsz=1280 save=true patience=50 resume=true
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
